# %%
import numpy as np
import pandas as pd
from sklearn import model_selection, preprocessing
from sklearn import linear_model
from sklearn.metrics import f1_score

# %%
patients = pd.read_csv('../../mimic3/data/PATIENTS.csv')
admissions = pd.read_csv('../../mimic3/data/ADMISSIONS.csv')
dias = pd.read_csv('../../mimic3/data/DIAGNOSES_ICD.csv')
diag_dict = pd.read_csv('../../mimic3/data/D_ICD_DIAGNOSES.csv')
pres = pd.read_csv('../../mimic3/data/PRESCRIPTIONS.csv')
# Out:
# /scratch/xp_python3.6/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2728: DtypeWarning: Columns (11) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
patients.count()
# Out:
# ROW_ID         46520
# SUBJECT_ID     46520
# GENDER         46520
# DOB            46520
# DOD            15759
# DOD_HOSP        9974
# DOD_SSN        13378
# EXPIRE_FLAG    46520
# dtype: int64

# %%
pats = patients[['SUBJECT_ID','GENDER','EXPIRE_FLAG']]

# %%
admissions
# Out:
#        ROW_ID  SUBJECT_ID  HADM_ID            ADMITTIME            DISCHTIME  \
# 0          21          22   165315  2196-04-09 12:26:00  2196-04-10 15:54:00
# 1          22          23   152223  2153-09-03 07:15:00  2153-09-08 19:10:00
# 2          23          23   124321  2157-10-18 19:34:00  2157-10-25 14:00:00
# 3          24          24   161859  2139-06-06 16:14:00  2139-06-09 12:48:00
# 4          25          25   129635  2160-11-02 02:06:00  2160-11-05 14:55:00
# 5          26          26   197661  2126-05-06 15:16:00  2126-05-13 15:00:00
# 6          27          27   134931  2191-11-30 22:16:00  2191-12-03 14:45:00
# 7          28          28   162569  2177-09-01 07:15:00  2177-09-06 16:00:00
# 8          29          30   104557  2172-10-14 14:17:00  2172-10-19 14:37:00
# 9          30          31   128652  2108-08-22 23:27:00  2108-08-30 15:00:00
# 10         31          32   175413  2170-04-04 08:00:00  2170-04-23 12:45:00
# ...

# %%
admissions = admissions.sort_values(by=['SUBJECT_ID','ADMITTIME'],ascending=[1,1])

# %%
adm_drops = admissions.drop_duplicates(subset=['SUBJECT_ID'],keep='last')

# %%
adm_drops
# Out:
#        ROW_ID  SUBJECT_ID  HADM_ID            ADMITTIME            DISCHTIME  \
# 211         1           2   163353  2138-07-17 19:04:00  2138-07-21 15:48:00
# 212         2           3   145834  2101-10-20 19:08:00  2101-10-31 13:58:00
# 213         3           4   185777  2191-03-16 00:28:00  2191-03-23 18:41:00
# 214         4           5   178980  2103-02-02 04:31:00  2103-02-04 12:15:00
# 215         5           6   107064  2175-05-30 07:15:00  2175-06-15 16:00:00
# 216         6           7   118037  2121-05-23 15:05:00  2121-05-27 11:57:00
# 217         7           8   159514  2117-11-20 10:22:00  2117-11-24 14:20:00
# 218         8           9   150750  2149-11-09 13:06:00  2149-11-14 10:15:00
# 219         9          10   184167  2103-06-28 11:36:00  2103-07-06 12:10:00
# 220        10          11   194540  2178-04-16 06:18:00  2178-05-11 19:00:00
# 221        11          12   112213  2104-08-07 10:15:00  2104-08-20 02:57:00
# ...

# %%
profs = pd.merge(adm_drops,dias,how='inner',on=['SUBJECT_ID','HADM_ID'])

# %%
profs = profs[profs.SEQ_NUM==1.0]

# %%
profs = profs.drop(['ROW_ID_x','HADM_ID','DEATHTIME','DIAGNOSIS','HAS_CHARTEVENTS_DATA','ROW_ID_y','SEQ_NUM'], axis=1)

# %%
final_data = pd.merge(pats,profs,how='inner',on='SUBJECT_ID')

# %%
final_data = final_data.drop(['HOSPITAL_EXPIRE_FLAG','DISCHARGE_LOCATION'], axis=1)

# %%
final_data.to_csv('mimic3_expire_prediction_data.csv',index=False)
